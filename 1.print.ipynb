# %%
print ()

# %%
print ("Welcome to Hope AI class")
# Out:
# Welcome to Hope AI class

# %%
print ("123456Vijaya_Lakshmi0987")
# Out:
# 123456Vijaya_Lakshmi0987

# %%
Print ("Hai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print ("Hai")
#
# NameError: name 'Print' is not defined
