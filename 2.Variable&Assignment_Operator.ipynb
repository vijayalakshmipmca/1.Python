# %%
Num1 = 10
Num2 = 30
Total = Num1 + Num2

# %%
Num1 = 10
Num2 = 30
Total = Num1 + Num2
print ("Total")
# Out:
# Total

# %%
Num1 = 10
Num2 = 30
Total = Num1 + Num2
print ("Total": Total)
# Out:
#   Cell In[5], line 4
#     print ("Total": Total)
#                   ^
# SyntaxError: invalid syntax

# %%
Num1 = 10
Num2 = 30
Total = Num1 + Num2
print ("Total : ", Total)
# Out:
# Total :  40

# %%
Num1 = 10
Num2 = 30
Total = Num1 + Num2
Difference = Num2 - Num1
print ("Total : ", Total)
print ("Difference : ", Difference)
# Out:
# Total :  40
# Difference :  20

# %%
First Name  = "Vijaya Lakshmi Palanisamy"
# Out:
#   Cell In[10], line 1
#     First Name  = "Vijaya Lakshmi Palanisamy"
#           ^
# SyntaxError: invalid syntax

# %%
First_Name  = "Vijaya Lakshmi"
SecondName = "Palanisamy"
print ("Name :", First_Name + " " + SecondName)
# Out:
# Name : Vijaya Lakshmi Palanisamy

# %%
3rdName = "Vijaya"
print ("Name : "), 3rdName)
# Out:
#   Cell In[12], line 1
#     3rdName = "Vijaya"
#     ^
# SyntaxError: invalid decimal literal

# %%
cityName = "Tiruppur"
print ("City Name : ", cityName)
# Out:
# City Name :  Tiruppur

# %%
Number1 = 100
Number2 = 300
Total = Number1 + Number2
Difference = Number2 - Number1
Product = Number1 * Number2
print ("The addition of two numbers \nNumber1 is : ", Number1  )
print ("Number2 is : " , Number2)
print ("The Answer is : ", Total)
# Out:
# The addition of two numbers
# Number1 is :  100
# Number2 is :  300
# The Answer is :  400

# %%
Number1 = 100
Number2 = 300
Total = Number1 + Number2
Difference = Number2 - Number1
Product = Number1 * Number2
print ("The addition of two numbers \nNumber1 is : ", Number1  )
print ("Number2 is : " , Number2)
print ("The Answer is : ", Total)

print ("The difference of two numbers \nNumber1 is : ", Number1  )
print ("Number2 is : " , Number2)
print ("The Answer is : ", Difference)

print ("The product of two numbers \nNumber1 is : ", Number1  )
print ("Number2 is : " , Number2)
print ("The Answer is : ", Product)
# Out:
# The addition of two numbers
# Number1 is :  100
# Number2 is :  300
# The Answer is :  400
# The difference of two numbers
# Number1 is :  100
# Number2 is :  300
# The Answer is :  200
# The product of two numbers
# Number1 is :  100
# Number2 is :  300
# The Answer is :  30000
