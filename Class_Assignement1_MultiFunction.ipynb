# %%
#from <python file name library file> import <class name>
from MultipleFunctionsFile import multifunction

# %%
import MultipleFunctionsFile

# %%
import importlib
importlib.reload(MultipleFunctionsFile)
# Out:
# <module 'MultipleFunctionsFile' from 'E:\\HOPE_AI\\Python\\MultipleFunctionsFile.py'>

# %%
obj = MultipleFunctionsFile.multifunction()

# %%
# %load_ext autoreload
# %autoreload 2
import MultipleFunctionsFile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
multifunction.agecalc()
# Out:
# Enter your Age :  33
# Adult
# 'Adult'

# %%
multifunction.bmicalc()
# Out:
# Enter the BMI Index: 35
# Very Overweight
# 'Very Overweight'

# %%
multifunction.addition()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 multifunction.addition()
#
# TypeError: multifunction.addition() missing 2 required positional arguments: 'num1' and 'num2'

# %%
multifunction.addition(12,23)
# Out:
# 35

# %%
multifunction.subtraction(120,20)
# Out:
# 100

# %%
multifunction.Multiple(120,20)
# Out:
# 2400

# %%
multifunction.OddEven()
# Out:
# Enter a number: 355
# 355 is Odd number

# %%
multifunction.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multifunction.Elegible()
# Out:
# Your Gender: fEMALE
# Your Age: 35
# ELIGIBLE

# %%
multifunction.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
multifunction.percentage()
# Out:
# Subject1= 100
# Subject2= 99
# Subject3= 98
# Subject4= 97
# Subject5= 96
# Total : 490
# Percentage : 98.0

# %%
multifunction.triangle()
# Out:
# Height: 22
# Breadth: 12
# Area formula: (Height*Breadth)/2
# Area of Triangle: 132.0
# Height1: 3
# Height2: 4
# Breadth: 5
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 12
