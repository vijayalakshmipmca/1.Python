# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#Corrected code: Colon missing for 'for' loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#Corrected code: concatenation cant be with str and int so convert str to int
a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#Corrected code: colon missing for function add_numbers(a, b), indentation for def
def add_numbers(a, b):
    return a + b

# %%
add_numbers(2,4)
# Out:
# 6

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
#   Cell In[10], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
#Corrected code: indentation for 'numbers', numbers - range is not correct

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#Corrected code: Parentheses missing for print statement

print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
#corrected code: Divide by 0 is not allowed , ZeroDivisionError
x = 5 / 1
print(x)
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#corrected code : concatenation of strint and int not allowed. convert int to str
name = "Alice" 
age =  25 
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#corrected code : range from , range to is not alligned with step count.. either to change range from and to or the step ount
for i in range(-1, -10,-1):
    print(i)
# Out:
# -1
# -2
# -3
# -4
# -5
# -6
# -7
# -8
# -9

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#Corrected code 
x = 10
if x == 5:  #assignment operator is == for comparsion , not = is for assigning value to the variable
    print("x is 5")
else :
    print("x is not 5")
# Out:
# x is not 5

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
#Corrected code : colon is missing 
def greet(name):
    print("Hello, " + name)

# %%
greet("Viji")
# Out:
# Hello, Viji
