# %%
age = int(input("Enter your Age : "))
if (age == 18):
print("Adult")
else:
    print("Minor")
# Out:
#   Cell In[3], line 3
#     print("Adult")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = int(input("Enter your Age : "))
if (age == 18):
    print("Adult")
else:
    print("Minor")
# Out:
# Enter your Age :  18
# Adult

# %%
for Temp in range (1,11):
    print(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 for Temp in range (1,11):
# ----> 2     print(temp)
#
# NameError: name 'temp' is not defined

# %%
Temp = input("Enter the value for Temp: ")
for Temp in range (1,11):
    print("Temp :", temp)
# Out:
# Enter the value for Temp:  10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 Temp = input("Enter the value for Temp: ")
#       2 for Temp in range (1,11):
# ----> 3     print("Temp :", temp)
#
# NameError: name 'temp' is not defined

# %%
Temp = input("Enter the value for Temp: ")
for Temp in range (1,11):
    print("Temp :", Temp)
# Out:
# Enter the value for Temp:  10
# Temp : 1
# Temp : 2
# Temp : 3
# Temp : 4
# Temp : 5
# Temp : 6
# Temp : 7
# Temp : 8
# Temp : 9
# Temp : 10

# %%
def():
