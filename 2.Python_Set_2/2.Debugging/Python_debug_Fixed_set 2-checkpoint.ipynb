# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# %%
#corrected code: Math is not defined as its we have it in lower case 'math' here. case sensitive
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
#corrected code: Value to assign before it is calling for the local variable
def my_function():
    x = 10
    x += 5
    print(x)

my_function()
# Out:
# 15

# %%
#corrected code: another way to declare as global variable
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
#corrected code: assignment operator == to use for comparsion
x = 5
if x ==10:
    print("x is 10")
else :
    print("x is not 10")
# Out:
# x is not 10

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
#corrected code: sort it and then print it.
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))
# Out:
# None

# %%
#corrected code: return to use to get the value
def square(n):
    return n * n
print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#corrected code: its immutable, cannot change after created
my_tuple = (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
#corrected code: arguments is missing
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Alice and I am 25 years old
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#corrected code : 2 different objects in the list, value not the matter
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#corrected code : ANOTHER WAY
a = [1, 2, 3]
b = a
if a is b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
#corrected code: step count should be negative to provide the output as default it is +1 so wont show any result
for i in range(5, 1 , -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

# %%
#corrected code: within quotes to provide for string as its not a variable
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
